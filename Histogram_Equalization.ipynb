# %% [markdown]
# <a href="https://colab.research.google.com/github/Josephjyinn516/Imaging-Processing/blob/main/Histogram_Equalization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

figsize = (10, 10)

# %%
I = cv2.imread("Unequalized_Hawkes_Bay_NZ.jpg", 0)

plt.figure(figsize = figsize)
plt.imshow(I, cmap = "gray", vmin = 0, vmax = 255)
plt.title("Original Image")
plt.show()
